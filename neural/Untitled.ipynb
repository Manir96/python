# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Sequential
from tensorflow import keras
import os

# %%
Data = pd.read_csv('Sample-Dataset-Sheet4.csv')

# %%
Data
# Out:
#       Unnamed: 0  BranchCode  LoanTerm  Gender  HomeType  FamilyMember  \
# 0              0          80         1       0         0             4
# 1              1          80         3       0         2             5
# 2              2          80         2       0         2             5
# 3              3          80         1       0         2             5
# 4              4          80         2       0         3             6
# ...          ...         ...       ...     ...       ...           ...
# 2348        2348          80         1       0         3             3
# 2349        2349          80         3       1         1             4
# 2350        2350          80         4       1         1             4
# 2351        2351          80         1       1         1             5
# 2352        2352          80         2       1         0             3
#
#       TotalWealth  PrincipalLoan  Frequency  PurposeCode  ...  DFS_Status  \
# 0              46         500000          0       10.550  ...           1
# 1               1          70000          2        1.290  ...           1
# 2               1          40000          2        1.640  ...           1
# 3              46         200000          0        1.133  ...           1
# 4              46          60000          2        1.152  ...           1
# ...           ...            ...        ...          ...  ...         ...
# 2348           21          50000          2        1.770  ...           1
# 2349           47         100000          0        5.152  ...           0
# 2350           47         400000          0        5.152  ...           0
# 2351           21         500000          0        5.152  ...           0
# 2352           21         500000          0        5.152  ...           1
#
#       Deposit  Withdrawal  Balance  duedays  DueType  LoanStatus  Unnamed: 17  \
# 0           0           0        0      180        3           0          NaN
# 1           0           0        0        0        2           0          NaN
# 2           0           0        0        0        2           0          NaN
# 3           0           0        0      660        0           0          NaN
# 4           0           0        0        0        2           0          NaN
# ...       ...         ...      ...      ...      ...         ...          ...
# 2348    10500           0    10929        0        2           1          NaN
# 2349    18000           0    18530        0        2           1          NaN
# 2350    18000           0    18530        0        2           1          NaN
# 2351     1000           0     1000        0        2           1          NaN
# 2352    24000           0    24165        0        2           1          NaN
#
#       Unnamed: 18  Unnamed: 19
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 2348          NaN          NaN
# 2349          NaN          NaN
# 2350          NaN          NaN
# 2351          NaN          NaN
# 2352          NaN          NaN
#
# [2353 rows x 21 columns]

# %%
Data = tf.keras.datasets.mnist

# %%
(x_train, y_train),(x_test, y_test) =Data.load_data()

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train, x_test = x_train/255, x_test/255

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13796\3269830848.py in <module>
# ----> 1 model = Sequential()
#       2 model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
#
# NameError: name 'Sequential' is not defined

# %%
model = tf.keras.models.Sequentaial([
    tf.keras.layers.Flatten(input_shape(28, 28)),
    tf.keras.layers.Dense(128, activation ='relu'),
    tf.keras.layers.dropout(0.2),
    tf.keras.layers.dense(10, activation ='softmax')
])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10792\2023580612.py in <module>
# ----> 1 model = tf.keras.models.Sequentaial([
#       2     tf.keras.layers.Flatten(input_shape(28, 28)),
#       3     tf.keras.layers.Dense(128, activation ='relu'),
#       4     tf.keras.layers.dropout(0.2),
#       5     tf.keras.layers.dense(10, activation ='softmax')
#
# AttributeError: module 'keras.api._v2.keras.models' has no attribute 'Sequentaial'

# %%
model.compile(optimizer ='adam',
             loss ='sparse_categorical_crossenttropy',
             matrics= ['accuracy']
             )

# %%
modell.fit(x_train, y_train,epochs=5)

# %%
model.evaluate(x_test, y_test)
